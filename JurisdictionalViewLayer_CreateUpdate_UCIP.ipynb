# %% [markdown]
# # Create & Update AGOL View Layers Based on Jurisdictional Boundaries
# ## Utah Critical Infrastructure Prioritization (UCIP) Tool -- Utah DEM
# This script is intended to manage hosted feature layers associated with the UCIP tool, including creating or deleting view layers filtered to specific geographies as well as updating all associated information with those view layers based on updates to the master layer. Particularly, this script allows updates to view layers of all 350+ jurisdictions in Utah to match new or updated fields in the master layer, symbology, pop-ups as well as form info (for editing or smart forms).

# %% [markdown]
# ### Import Libraries and Sign in to active GIS

# %%
from arcgis.gis import GIS
from arcgis.gis import ContentManager
from arcgis.features import FeatureLayerCollection
import json
import getpass
import arcpy



# Set variables, get AGOL username and password
portal_url = arcpy.GetActivePortalURL()
#print(portal_url)

my_agol = GIS(portal_url,"GIS@UtahDEM")



cm = ContentManager(my_agol)

# %% [markdown]
# ### Assign Master Hosted Feature Layer

# %%
# The Hosted Feature Layer containing a statewide dataset (Currently UCIP_Live_Layer)
#ucip_locs = my_agol.content.get('b81c64945f004ef28e9dba448e0a677e')
#ucip_locs = my_agol.content.get('419155dca4844b94b44c68f68b4b4ccb')
ucip_locs = my_agol.content.get('f3e43dcc7fc3495ea8731597b63b690d') #UCIP_Live_Layer


ucip_locs_flc = FeatureLayerCollection.fromitem(ucip_locs)
ucip_locs_layer = ucip_locs.layers[0]
ucip_properties = ucip_locs_layer.properties
ucip_symbology = (ucip_properties["drawingInfo"])

# %% [markdown]
# ### Assign Boundary/Jurisdictional Layer(s)

# %%
# The Hosted Feature Layer containing the regional division, counties and counties + municipalities

counties = my_agol.content.get('5d55fd5a8ad34448a32b2b5e34ce9ab9').layers[0].query() #just counties
counties_munis_gap = my_agol.content.get('c29faaea33da4cb680bf4a0e6a676732').layers[0].query() #gap in counties where municipalities are, plus municipalities
counties_munis = my_agol.content.get('6e5e56892ecb4be5990467419f69d248').layers[0].query()#counties and municipalities overlapping
counties_gaps = my_agol.content.get('f98099791f8745ae8159e27735610b3f').layers[0].query() #just counties with gaps where municipalities are

# Get the Spatial Reference
spat_ref = counties_munis.spatial_reference

#For all items below this, switching counties with county_munis will
#change the geometry to include counties and municipalities'''

# %% [markdown]
# ### Collect To-Update Info from Master Hosted Feature Layer

# %%
fields = ucip_properties.fields

layer_data=ucip_locs.get_data()
drawingInfo = layer_data["layers"][0]["layerDefinition"]["drawingInfo"]
formInfo=layer_data["layers"][0]["formInfo"]
popupInfo=layer_data["layers"][0]["popupInfo"]

print(json.dumps(layer_data))

# %% [markdown]
# ### Create or Update View Layers Based on Jurisdiction
# This script will create a view layer based on the jurisdiction if it does not already exist. If it does exist, it will update the view layer to match the fields/pop-up info/symbology/form info to match the master hosted feature layer. There is also a section to check whether the layer has been recently updated (in case the script stops and has to restart).

# %%
import datetime


# Loop through the regional division to create the views or update existing views for ALL JURISDICTIONS
for index, county in enumerate(counties_munis):
    county_name = counties_munis.features[index].attributes['NAME']
    print(county_name)
    view_name = 'UCIP_' + county_name + "_LIVE_View"
    print(view_name)
    
    
    # Get the geometry for the regions
    view_geom = counties_munis.features[index].geometry.get('rings')
    name_avail = cm.is_service_name_available(service_name = view_name,service_type = "featureService")
    
    
    # Check if view exists
    if  name_avail == True:
        new_view = ucip_locs_flc.manager.create_view(name=view_name)
        # Search for newly created View
        view_search = my_agol.content.search(view_name)[0]
        view_flc = FeatureLayerCollection.fromitem(view_search)

        service_layer = view_flc.layers[0]
        layerTags = [county_name,view_name,"UCIP","View Layer","Live"]

        # Populate the update_dict with the geometry and the spatial reference
        update_dict = {"tags":layerTags,"viewLayerDefinition":{"filter":
                                                               {"operator":"esriSpatialRelContains","value":
                                                                {"geometryType":"esriGeometryPolygon","geometry":
                                                                 {"rings": view_geom,
                                                                  "spatialReference":spat_ref}}}}}
        
        
        # Assign category to new view layer
        service_layer_id=view_search.id
        my_agol.content.categories.assign_to_items(items = [{service_layer_id: {
                                                     "categories": ["/Categories/UCIP"]}}])
        
        
        # Update the definition to include the Area of Interest
        service_layer.manager.update_definition(update_dict)
        
        
        # Move layer to UCIP live folder
        view_search.move(folder="UCIP - LIVE")

        print("Added ",view_name)
    
    else:
        print(view_name," Exists")
        
        
        # Search for newly View
        view_search = my_agol.content.search(view_name)[0]
        view_flc = FeatureLayerCollection.fromitem(view_search)
        update_date = datetime.date.fromtimestamp(view_search.modified/1000)
        print(update_date)
        print(datetime.datetime.today())
        
        if update_date == datetime.date.today():
            print("Recently Updated")
        else:

            service_layer = view_flc.layers[0]
            layerTags = [county_name,view_name,"UCIP","View Layer"]


            # Populate the update_dict with the geometry and the spatial reference
            dict_fields = [{"name":f"{f.name}","visible":True} for f in fields]
            #print(dict_fields)
            view_layer = view_search.get_data()
            view_layer["layers"][0]["popupInfo"]=popupInfo
            view_layer["layers"][0]["formInfo"]=formInfo
            view_layer["layers"][0]["layerDefinition"]["drawingInfo"]=drawingInfo

            
            #Update the layer tags and fields
            update_dict_fields = {"tags":layerTags,"fields":dict_fields}
            service_layer.manager.update_definition(update_dict_fields)
            view_search.update(update_dict_fields)

            
            # Update the layer symbology, pop-up info and form-info
            update_dict = {}
            update_dict = {"text":json.dumps(view_layer)}
            view_search.update(update_dict)

            
            # Assign category to new view layer
            service_layer_id=view_search.id
            my_agol.content.categories.assign_to_items(items = [{service_layer_id: {
                                                         "categories": ["/Categories/UCIP"]}}])

            # Add layer to UCIP_LIVE folder
            view_search.move(folder="UCIP - LIVE")

            print("Updated ",view_name)

print('Done!')

# %% [markdown]
# ### Create layers for each county to be used for VIEW ONLY (Not Editing)
# *Needs to be updated to reflect symbology/pop-ups/form info/fields

# %%
# Loop through the regional division to create the views COUNTIES ONLY VIEW ONLY
for index, county in enumerate(counties):
    county_name = counties.features[index].attributes['NAME']
    print(county_name)
    view_name = 'UCIP_' + county_name + "_LIVE_ViewONLY"
    print(view_name)
    
    # Get the geometry for the regions
    view_geom = counties.features[index].geometry.get('rings')
    name_avail = cm.is_service_name_available(service_name = view_name,service_type = "featureService")
    
    # Check if view exists
    if  name_avail == True:
        new_view = ucip_locs_flc.manager.create_view(name=view_name)
        
        # Search for newly created View
        view_search = my_agol.content.search(view_name)[0]
        view_flc = FeatureLayerCollection.fromitem(view_search)

        service_layer = view_flc.layers[0]
        layerTags = [county_name,view_name,"UCIP","View Layer","Live"]


        
        # Populate the update_dict with the geometry and the spatial reference
        update_dict = {"tags":layerTags,"viewLayerDefinition":{"filter":
                                                               {"operator":"esriSpatialRelContains","value":
                                                                {"geometryType":"esriGeometryPolygon","geometry":
                                                                 {"rings": view_geom,
                                                                  "spatialReference":spat_ref}}}}}
        
        # Assign category to new view layer
        service_layer_id=view_search.id
        my_agol.content.categories.assign_to_items(items = [{service_layer_id: {
                                                     "categories": ["/Categories/UCIP"]}}])
                

        # Update the definition to include the Area of Interest
        service_layer.manager.update_definition(update_dict)
        
        # Move layer to UCIP live folder
        view_search.move(folder="UCIP - LIVE")

        print("Created ",view_name)
        
    else:
        view_search = my_agol.content.search(view_name)[0]
        view_flc = FeatureLayerCollection.fromitem(view_search)

        service_layer = view_flc.layers[0]
        layerTags = [county_name,view_name,"UCIP","View Layer","Live"]

        # Populate the update_dict with the geometry and the spatial reference
        update_dict = {"tags":layerTags,"viewLayerDefinition":{"filter":
                                                               {"operator":"esriSpatialRelContains","value":
                                                                {"geometryType":"esriGeometryPolygon","geometry":
                                                                 {"rings": view_geom,
                                                                  "spatialReference":spat_ref}}}}}
        
        # Assign category to new view layer
        service_layer_id=view_search.id
        my_agol.content.categories.assign_to_items(items = [{service_layer_id: {
                                                     "categories": ["/Categories/UCIP"]}}])
        

        # Update the definition to include the Area of Interest
        service_layer.manager.update_definition(update_dict)
        
        # Move layer to UCIP live folder
        view_search.move(folder="UCIP - LIVE")

        print("Updated ",view_name)

print('Done!')

# %% [markdown]
# ### Update only one jurisdiction

# %%
import datetime

# Loop through the regional division to create the views or update existing views for ALL JURISDICTIONS
for index, county in enumerate(counties_munis):
    county_name = counties_munis.features[index].attributes['NAME']
    print(county_name)
    view_name = 'UCIP_' + county_name + "_LIVE_View"
    print(view_name)
    
    # Get the geometry for the regions
    view_geom = counties_munis.features[index].geometry.get('rings')
    name_avail = cm.is_service_name_available(service_name = view_name,service_type = "featureService")
    
    # Check if view exists
    if  view_name == 'UCIP_West Jordan_LIVE_View':
        print(view_name," Exists")
        
        # Search for View
        view_search = my_agol.content.search(view_name)[0]
        view_flc = FeatureLayerCollection.fromitem(view_search)
        update_date = datetime.date.fromtimestamp(view_search.modified/1000)
        print(update_date)
        print(datetime.datetime.today())
        
        if update_date == datetime.date.today():
            print("Recently Updated")
        else:

            service_layer = view_flc.layers[0]
            layerTags = [county_name,view_name,"UCIP","View Layer"]


            # Populate the update_dict with the geometry and the spatial reference
            dict_fields = [{"name":f"{f.name}","visible":True} for f in fields]
            #print(dict_fields)
            view_layer = view_search.get_data()
            view_layer["layers"][0]["popupInfo"]=popupInfo
            view_layer["layers"][0]["formInfo"]=formInfo
            view_layer["layers"][0]["layerDefinition"]["drawingInfo"]=drawingInfo

            #Update the layer tags and fields
            update_dict_fields = {"tags":layerTags,"fields":dict_fields}
            service_layer.manager.update_definition(update_dict_fields)
            view_search.update(update_dict_fields)

            # Update the layer symbology, pop-up info and form-info
            update_dict = {}
            update_dict = {"text":json.dumps(view_layer)}
            view_search.update(update_dict)

            # Assign category to new view layer
            service_layer_id=view_search.id
            my_agol.content.categories.assign_to_items(items = [{service_layer_id: {
                                                         "categories": ["/Categories/UCIP"]}}])

            # Add layer to UCIP_LIVE folder
            view_search.move(folder="UCIP - LIVE")

            print("Updated ",view_name)
    else:
        print("Not Today ",view_name,", not today.......")

print('Done!')

# %% [markdown]
# ### DEPRECATED: Create/Update Jurisdictional Views for Counties Only

# %%
# Loop through the regional division to create the views COUNTIES ONLY
import json
for index, county in enumerate(counties):
    county_name = counties.features[index].attributes['NAME']
    print(county_name)
    view_name = 'UCIP_' + county_name + "_All_LIVE_View"
    print(view_name)
    # Get the geometry for the regions
    view_geom = counties.features[index].geometry.get('rings')
    name_avail = cm.is_service_name_available(service_name = view_name,service_type = "featureService")
    # Check if view exists
    if  name_avail == True:
        new_view = ucip_locs_flc.manager.create_view(name=view_name)
        # Search for newly created View
        view_search = my_agol.content.search(view_name)[0]
        view_flc = FeatureLayerCollection.fromitem(view_search)

        service_layer = view_flc.layers[0]
        layerTags = [county_name,view_name,"UCIP","View Layer","Live"]


        
        # Populate the update_dict with the geometry and the spatial reference
        update_dict = {"tags":layerTags,"viewLayerDefinition":{"filter":
                                                               {"operator":"esriSpatialRelContains","value":
                                                                {"geometryType":"esriGeometryPolygon","geometry":
                                                                 {"rings": view_geom,
                                                                  "spatialReference":spat_ref}}}}}
        
        # Assign category to new view layer
        service_layer_id=view_search.id
        my_agol.content.categories.assign_to_items(items = [{service_layer_id: {
                                                     "categories": ["/Categories/UCIP"]}}])
        
        # Add layer to UCIP_LIVE folder
        

        # Update the definition to include the Area of Interest
        service_layer.manager.update_definition(update_dict)
        
        # Move layer to UCIP live folder
        view_search.move(folder="UCIP - LIVE")

        print("Added ",view_name)
    elif view_name == "UCIP_WASHINGTON_All_LIVE_View":
        view_search = my_agol.content.search(view_name)[0]
        print(view_search)
        view_flc = FeatureLayerCollection.fromitem(view_search)

        service_layer = view_flc.layers[0]
        layerTags = [county_name,view_name,"UCIP","View Layer","Live"]
        dict_fields = [{"name":f"{f.name}","visible":True} for f in fields]
        
        view_layer = view_search.get_data()
        #print(json.dumps(view_layer))
        view_layer["layers"][0]["popupInfo"]=popupInfo
        view_layer["layers"][0]["formInfo"]=formInfo
        view_layer["layers"][0]["layerDefinition"]["drawingInfo"]=drawingInfo
        print(json.dumps(view_layer))
        



        
        # Populate the update_dict with the geometry and the spatial reference
        #update_dict = {"tags":layerTags,"drawingInfo":ucip_symbology,"fields":dict_fields}
        update_dict = {}
        update_dict = {"text":json.dumps(view_layer)}
        
        # Assign category to new view layer
        service_layer_id=view_search.id
        my_agol.content.categories.assign_to_items(items = [{service_layer_id: {
                                                     "categories": ["/Categories/UCIP"]}}])
        
        # Add layer to UCIP_LIVE folder
        

        # Update the definition to include the Area of Interest
        #ucip_properties2 = ucip_properties
        #del ucip_properties2['editingInfo']
        #service_layer.manager.update_definition(update_dict)
        view_search.update(update_dict)
        
        # Move layer to UCIP live folder
        view_search.move(folder="UCIP - LIVE")

        print("Updated ",view_name)
    else:
        print("Exists")

# %% [markdown]
# ### DEPRECATED: Test Definition to Update Layers

# %%
import json

def update_layer_def(item):
    item_data = item.get_data()
    if item_data is not None:
        # Here note we are changing a specific part of the Layer Definition
        layer_def = item_data['layers'][3]['layerDefinition']
        print("*******************ORIGINAL DEFINITION*********************")
        print(json.dumps(item_data, indent=4, sort_keys=True))

        # Open JSON file containing symbology update
        with open('/path/to/drawingInfo.json') as json_data:
            data = json.load(json_data)

        # Set the drawingInfo equal to what is in JSON file
        layer_def['drawingInfo'] = data

        # Set the item_properties to include the desired update
        item_properties = {"text": json.dumps(item_data)}

        # 'Commit' the updates to the Item
        item.update(item_properties=item_properties)

        # Print item_data to see that changes are reflected
        new_item_data = item.get_data()
        print("***********************NEW DEFINITION**********************")
        print(json.dumps(new_item_data, indent=4, sort_keys=True))
    
    else:
        print("There is no Layer Definition at the moment..creating one...")
        create_layer_def(item)

# %%
# Get Master Layer Info

import arcgis
resturl=dict(ucip_locs)["url"]
layerurl=str(resturl)+"/"+str(0)
layer=arcgis.features.FeatureLayer(layerurl)

print(layerurl+"?f=pjson")
print(layer.properties)
# Out:
# https://services6.arcgis.com/KaHXE9OkiB9e63uE/arcgis/rest/services/UCIP_Master_Layer_081822_00865/FeatureServer/0?f=pjson
# {
#   "currentVersion": 11.2,
#   "id": 0,
#   "name": "UCIP_Testing_Survey",
#   "type": "Feature Layer",
#   "serviceItemId": "f3e43dcc7fc3495ea8731597b63b690d",
#   "sourceSchemaChangesAllowed": true,
#   "hasViews": true,
#   "displayField": "assessor_name",
#   "description": "",
#   "copyrightText": "",
#   "defaultVisibility": true,
#   "ownershipBasedAccessControlForFeatures": {
#     "allowOthersToQuery": true,
#     "allowOthersToDelete": true,
#     "allowOthersToUpdate": true,
#     "allowAnonymousToQuery": true,
#     "allowAnonymousToUpdate": false,
#     "allowAnonymousToDelete": false
#   },
#   "editFieldsInfo": {
#     "creationDateField": "CreationDate",
#     "creatorField": "Creator",
#     "editDateField": "EditDate",
#     "editorField": "Editor"
#   },
#   "editingInfo": {
#     "lastEditDate": 1700081788781,
#     "schemaLastEditDate": 1700081788781,
#     "dataLastEditDate": 1700081788781
#   },
#   "relationships": [],
#   "isDataVersioned": false,
#   "hasContingentValuesDefinition": false,
#   "supportsAppend": true,
#   "supportsCalculate": true,
#   "supportsASyncCalculate": true,
#   "supportsTruncate": false,
#   "supportsAttachmentsByUploadId": true,
#   "supportsAttachmentsResizing": true,
#   "supportsRollbackOnFailureParameter": true,
#   "supportsStatistics": true,
#   "supportsExceedsLimitStatistics": true,
#   "supportsAdvancedQueries": true,
#   "supportsValidateSql": true,
#   "supportsCoordinatesQuantization": true,
#   "supportsLayerOverrides": true,
#   "supportsTilesAndBasicQueriesMode": true,
#   "supportsFieldDescriptionProperty": true,
#   "supportsQuantizationEditMode": true,
#   "supportsApplyEditsWithGlobalIds": true,
#   "supportsReturningQueryGeometry": true,
#   "supportsOBACForAnonymousUsers": true,
#   "advancedQueryCapabilities": {
#     "supportsPagination": true,
#     "supportsQueryAttachmentsCountOnly": true,
#     "supportsPaginationOnAggregatedQueries": true,
#     "supportsQueryRelatedPagination": true,
#     "supportsQueryWithDistance": true,
#     "supportsReturningQueryExtent": true,
#     "supportsStatistics": true,
#     "supportsOrderBy": true,
#     "supportsDistinct": true,
#     "supportsQueryWithResultType": true,
#     "supportsSqlExpression": true,
#     "supportsAdvancedQueryRelated": true,
#     "supportsCountDistinct": true,
#     "supportsPercentileStatistics": true,
#     "supportsSpatialAggregationStatistics": true,
#     "supportedSpatialAggregationStatistics": [
#       "EnvelopeAggregate",
#       "CentroidAggregate",
#       "ConvexHullAggregate"
#     ],
#     "supportsQueryAttachments": true,
#     "supportsLod": true,
#     "supportsQueryWithLodSR": false,
#     "supportedLodTypes": [
#       "geohash"
#     ],
#     "supportsReturningGeometryCentroid": false,
#     "supportsReturningGeometryEnvelope": true,
#     "supportsQueryWithDatumTransformation": true,
#     "supportsCurrentUserQueries": true,
#     "supportsHavingClause": true,
#     "supportsOutFieldSQLExpression": true,
#     "supportsMaxRecordCountFactor": true,
#     "supportsTopFeaturesQuery": true,
#     "supportsDisjointSpatialRel": true,
#     "supportsQueryWithCacheHint": true,
#     "supportedOperationsWithCacheHint": [
#       "query",
#       "queryTopFilter",
#       "queryAnalytics",
#       "queryAttachments",
#       "queryRelated"
#     ],
#     "supportsQueryAttachmentsWithReturnUrl": true,
#     "supportsQueryAnalytic": true,
#     "supportsDefaultSR": true,
#     "supportsFullTextSearch": true
#   },
#   "advancedQueryAnalyticCapabilities": {
#     "supportsLinearRegression": true,
#     "supportsAsync": true,
#     "supportsPercentileAnalytic": true
#   },
#   "advancedEditingCapabilities": {
#     "supportedSqlFormatsInCalculate": [
#       "standard"
#     ],
#     "supportsAsyncApplyEdits": true,
#     "supportsReturnEditResults": true,
#     "supportsApplyEditsbyUploadID": true,
#     "supportedApplyEditsUploadIDFormats": "JSON"
#   },
#   "infoInEstimates": [
#     "extent",
#     "count"
#   ],
#   "useStandardizedQueries": true,
#   "geometryType": "esriGeometryPoint",
#   "minScale": 0,
#   "maxScale": 0,
#   "extent": {
#     "xmin": -11341463.22682926,
#     "ymin": 36.23433861250738,
#     "xmax": 113.883202277664,
#     "ymax": 3748285.0749657,
#     "spatialReference": {
#       "wkid": 4326,
#       "latestWkid": 4326
#     }
#   },
#   "drawingInfo": {
#     "renderer": {
#       "authoringInfo": {
#         "visualVariables": [
#           {
#             "type": "sizeInfo",
#             "minSliderValue": 13,
#             "maxSliderValue": 55
#           }
#         ]
#       },
#       "type": "uniqueValue",
#       "field1": "infrastructure_sector",
#       "uniqueValueInfos": [
#         {
#           "symbol": {
#             "type": "esriPMS",
#             "url": "ddb5b079c4462b691b059f0d7fef5609",
#             "imageData": "...",
#             "contentType": "image/png",
#             "width": 7,
#             "height": 7,
#             "angle": 0,
#             "xoffset": 0,
#             "yoffset": 0
#           },
#           "value": "Agriculture_and_Food",
#           "label": "Agriculture and Food"
#         },
#         {
#           "symbol": {
#             "type": "esriPMS",
#             "url": "b529505e84e24866d7addfc483244907",
#             "imageData": "...",
#             "contentType": "image/png",
#             "width": 7,
#             "height": 7,
#             "angle": 0,
#             "xoffset": 0,
#             "yoffset": 0
#           },
#           "value": "Banking_and_Finance",
#           "label": "Banking and Finance"
#         },
#         {
#           "symbol": {
#             "type": "esriPMS",
#             "url": "45bdbeead01a3d569ea61e5293ecfdf6",
#             "imageData": "...",
#             "contentType": "image/png",
#             "width": 7,
#             "height": 7,
#             "angle": 0,
#             "xoffset": 0,
#             "yoffset": 0
#           },
#           "value": "Chemical",
#           "label": "Chemical"
#         },
#         {
#           "symbol": {
#             "type": "esriPMS",
#             "url": "1d53cd9b245f46d5d296a06c297a3289",
#             "imageData": "...",
#             "contentType": "image/png",
#             "width": 7,
#             "height": 7,
#             "angle": 0,
#             "xoffset": 0,
#             "yoffset": 0
#           },
#           "value": "Commercial_Facilities",
#           "label": "Commercial Facilities"
#         },
#         {
#           "symbol": {
#             "type": "esriPMS",
#             "url": "fcb998e160c4b574b37d2e25016e6571",
#             "imageData": "...",
#             "contentType": "image/png",
#             "width": 7,
#             "height": 7,
#             "angle": 0,
#             "xoffset": 0,
#             "yoffset": 0
#           },
#           "value": "Critical_Manufacturing",
#           "label": "Critical Manufacturing"
#         },
#         {
#           "symbol": {
#             "type": "esriPMS",
#             "url": "be32b8e74417b1a34f522a31da3adaf2",
#             "imageData": "...",
#             "contentType": "image/png",
#             "width": 7,
#             "height": 7,
#             "angle": 0,
#             "xoffset": 0,
#             "yoffset": 0
#           },
#           "value": "Dams",
#           "label": "Dams"
#         },
#         {
#           "symbol": {
#             "type": "esriPMS",
#             "url": "3990f7a2a7a63ac23f00f7d5a5c00d3c",
#             "imageData": "...",
#             "contentType": "image/png",
#             "width": 7,
#             "height": 7,
#             "angle": 0,
#             "xoffset": 0,
#             "yoffset": 0
#           },
#           "value": "Defense_Industrial_Base",
#           "label": "Defense Industrial Base"
#         },
#         {
#           "symbol": {
#             "type": "esriPMS",
#             "url": "8c8f853c3626e8e2d11ed571956bede6",
#             "imageData": "...",
#             "contentType": "image/png",
#             "width": 7,
#             "height": 7,
#             "angle": 0,
#             "xoffset": 0,
#             "yoffset": 0
#           },
#           "value": "Emergency_Services",
#           "label": "Emergency Services"
#         },
#         {
#           "symbol": {
#             "type": "esriPMS",
#             "url": "988d45d595512d18b21998df9f53c9b5",
#             "imageData": "...",
#             "contentType": "image/png",
#             "width": 7,
#             "height": 7,
#             "angle": 0,
#             "xoffset": 0,
#             "yoffset": 0
#           },
#           "value": "Energy",
#           "label": "Energy"
#         },
#         {
#           "symbol": {
#             "type": "esriPMS",
#             "url": "ea5950f56b61bdbdf9f15515cbaa46ee",
#             "imageData": "...",
#             "contentType": "image/png",
#             "width": 7,
#             "height": 7,
#             "angle": 0,
#             "xoffset": 0,
#             "yoffset": 0
#           },
#           "value": "Government_Facilities",
#           "label": "Government Facilities"
#         },
#         {
#           "symbol": {
#             "type": "esriPMS",
#             "url": "cf57e81ddfb7d54acb289071df6df7dd",
#             "imageData": "...",
#             "contentType": "image/png",
#             "width": 7,
#             "height": 7,
#             "angle": 0,
#             "xoffset": 0,
#             "yoffset": 0
#           },
#           "value": "Information_Technologies",
#           "label": "Information Technologies"
#         },
#         {
#           "symbol": {
#             "type": "esriPMS",
#             "url": "d7b0e8f90e900c0407d136f6ea10dd7c",
#             "imageData": "...",
#             "contentType": "image/png",
#             "width": 7,
#             "height": 7,
#             "angle": 0,
#             "xoffset": 0,
#             "yoffset": 0
#           },
#           "value": "Nuclear_Reactors_Materials",
#           "label": "Nuclear Reactors, Materials, and Waste"
#         },
#         {
#           "symbol": {
#             "type": "esriPMS",
#             "url": "697922eb157363ea0cf1e11adbedecd8",
#             "imageData": "...",
#             "contentType": "image/png",
#             "width": 7,
#             "height": 7,
#             "angle": 0,
#             "xoffset": 0,
#             "yoffset": 0
#           },
#           "value": "Public_Health",
#           "label": "Public Health and Health Care"
#         },
#         {
#           "symbol": {
#             "type": "esriPMS",
#             "url": "e8baf820312306559bddf2fa2f2c5e55",
#             "imageData": "...",
#             "contentType": "image/png",
#             "width": 7,
#             "height": 7,
#             "angle": 0,
#             "xoffset": 0,
#             "yoffset": 0
#           },
#           "value": "Telecommunication",
#           "label": "Telecommunication"
#         },
#         {
#           "symbol": {
#             "type": "esriPMS",
#             "url": "ae5acaa72ad792f46268a4431781df8a",
#             "imageData": "...",
#             "contentType": "image/png",
#             "width": 7,
#             "height": 7,
#             "angle": 0,
#             "xoffset": 0,
#             "yoffset": 0
#           },
#           "value": "Transportation",
#           "label": "Transportation"
#         },
#         {
#           "symbol": {
#             "type": "esriPMS",
#             "url": "2c4592237838f1dd33d4d805c15a7267",
#             "imageData": "...",
#             "contentType": "image/png",
#             "width": 7,
#             "height": 7,
#             "angle": 0,
#             "xoffset": 0,
#             "yoffset": 0
#           },
#           "value": "Water_and_Water_Treatment",
#           "label": "Water and Water Treatment"
#         }
#       ],
#       "fieldDelimiter": ",",
#       "visualVariables": [
#         {
#           "type": "sizeInfo",
#           "valueExpressionTitle": "TotalScore",
#           "valueExpression": "// Write a script that returns a value that will be used to draw features.\n// For example, find the percentage of males:\n// Round(($feature.MalePop / $feature.TotalPop) * 100, 2)\n\nNumber($feature[\"Total_Score\"])",
#           "minSize": 15,
#           "maxSize": 30,
#           "minDataValue": 13,
#           "maxDataValue": 55,
#           "axis": "height",
#           "legendOptions": {
#             "title": "",
#             "showLegend": true
#           }
#         }
#       ]
#     },
#     "scaleSymbols": true,
#     "transparency": 0,
#     "labelingInfo": null
#   },
#   "allowGeometryUpdates": true,
#   "hasAttachments": true,
#   "attachmentProperties": [
#     {
#       "name": "id",
#       "fieldName": "ATTACHMENTID",
#       "isEnabled": true
#     },
#     {
#       "name": "globalId",
#       "fieldName": "AttachmentGlobalID",
#       "isEnabled": true
#     },
#     {
#       "name": "name",
#       "fieldName": "ATT_NAME",
#       "isEnabled": true
#     },
#     {
#       "name": "size",
#       "fieldName": "DATA_SIZE",
#       "isEnabled": true
#     },
#     {
#       "name": "contentType",
#       "fieldName": "CONTENT_TYPE",
#       "isEnabled": true
#     },
#     {
#       "name": "keywords",
#       "fieldName": "Keywords",
#       "isEnabled": true
#     },
#     {
#       "name": "exifInfo",
#       "fieldName": "ExifInfo",
#       "isEnabled": true
#     }
#   ],
#   "htmlPopupType": "esriServerHTMLPopupTypeAsHTMLText",
#   "hasM": false,
#   "hasZ": false,
#   "objectIdField": "OBJECTID",
#   "uniqueIdField": {
#     "name": "OBJECTID",
#     "isSystemMaintained": true
#   },
#   "globalIdField": "globalid",
#   "typeIdField": "infrastructure_sector",
#   "fields": [
#     {
#       "name": "OBJECTID",
#       "type": "esriFieldTypeOID",
#       "alias": "OBJECTID",
#       "sqlType": "sqlTypeOther",
#       "nullable": false,
#       "editable": false,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "globalid",
#       "type": "esriFieldTypeGlobalID",
#       "alias": "GlobalID",
#       "sqlType": "sqlTypeOther",
#       "length": 38,
#       "nullable": false,
#       "editable": false,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "county",
#       "type": "esriFieldTypeString",
#       "alias": "County:",
#       "sqlType": "sqlTypeOther",
#       "length": 255,
#       "nullable": true,
#       "editable": true,
#       "domain": {
#         "type": "codedValue",
#         "name": "cvd_county",
#         "mergePolicy": "esriMPTDefaultValue",
#         "splitPolicy": "esriSPTDefaultValue",
#         "codedValues": [
#           {
#             "name": "BEAVER",
#             "code": "BEAVER"
#           },
#           {
#             "name": "BOX ELDER",
#             "code": "BOX_ELDER"
#           },
#           {
#             "name": "CACHE",
#             "code": "CACHE"
#           },
#           {
#             "name": "CARBON",
#             "code": "CARBON"
#           },
#           {
#             "name": "DAGGETT",
#             "code": "DAGGETT"
#           },
#           {
#             "name": "DAVIS",
#             "code": "DAVIS"
#           },
#           {
#             "name": "DUCHESNE",
#             "code": "DUCHESNE"
#           },
#           {
#             "name": "EMERY",
#             "code": "EMERY"
#           },
#           {
#             "name": "GARFIELD",
#             "code": "GARFIELD"
#           },
#           {
#             "name": "GRAND",
#             "code": "GRAND"
#           },
#           {
#             "name": "IRON",
#             "code": "IRON"
#           },
#           {
#             "name": "JUAB",
#             "code": "JUAB"
#           },
#           {
#             "name": "KANE",
#             "code": "KANE"
#           },
#           {
#             "name": "MILLARD",
#             "code": "MILLARD"
#           },
#           {
#             "name": "MORGAN",
#             "code": "MORGAN"
#           },
#           {
#             "name": "PIUTE",
#             "code": "PIUTE"
#           },
#           {
#             "name": "RICH",
#             "code": "RICH"
#           },
#           {
#             "name": "SALT LAKE",
#             "code": "SALT_LAKE"
#           },
#           {
#             "name": "SAN JUAN",
#             "code": "SAN_JUAN"
#           },
#           {
#             "name": "SANPETE",
#             "code": "SANPETE"
#           },
#           {
#             "name": "SEVIER",
#             "code": "SEVIER"
#           },
#           {
#             "name": "SUMMIT",
#             "code": "SUMMIT"
#           },
#           {
#             "name": "TOOELE",
#             "code": "TOOELE"
#           },
#           {
#             "name": "UINTAH",
#             "code": "UINTAH"
#           },
#           {
#             "name": "UTAH",
#             "code": "UTAH"
#           },
#           {
#             "name": "WASATCH",
#             "code": "WASATCH"
#           },
#           {
#             "name": "WASHINGTON",
#             "code": "WASHINGTON"
#           },
#           {
#             "name": "WAYNE",
#             "code": "WAYNE"
#           },
#           {
#             "name": "WEBER",
#             "code": "WEBER"
#           }
#         ]
#       },
#       "defaultValue": null
#     },
#     {
#       "name": "Utah_City",
#       "type": "esriFieldTypeString",
#       "alias": "City:",
#       "sqlType": "sqlTypeOther",
#       "length": 255,
#       "nullable": true,
#       "editable": true,
#       "domain": {
#         "type": "codedValue",
#         "name": "cvd_cities",
#         "codedValues": [
#           {
#             "name": "Amalga",
#             "code": "Amalga"
#           },
#           {
#             "name": "Clarkston",
#             "code": "Clarkston"
#           },
#           {
#             "name": "Cornish",
#             "code": "Cornish"
#           },
#           {
#             "name": "Hyde Park",
#             "code": "Hyde Park"
#           },
#           {
#             "name": "Hyrum",
#             "code": "Hyrum"
#           },
#           {
#             "name": "Lewiston",
#             "code": "Lewiston"
#           },
#           {
#             "name": "Logan",
#             "code": "Logan"
#           },
#           {
#             "name": "Mendon",
#             "code": "Mendon"
#           },
#           {
#             "name": "Millville",
#             "code": "Millville"
#           },
#           {
#             "name": "Newton",
#             "code": "Newton"
#           },
#           {
#             "name": "Nibley",
#             "code": "Nibley"
#           },
#           {
#             "name": "North Logan",
#             "code": "North Logan"
#           },
#           {
#             "name": "Paradise",
#             "code": "Paradise"
#           },
#           {
#             "name": "Providence",
#             "code": "Providence"
#           },
#           {
#             "name": "Richmond",
#             "code": "Richmond"
#           },
#           {
#             "name": "River Heights",
#             "code": "River Heights"
#           },
#           {
#             "name": "Smithfield",
#             "code": "Smithfield"
#           },
#           {
#             "name": "Trenton",
#             "code": "Trenton"
#           },
#           {
#             "name": "Wellsville",
#             "code": "Wellsville"
#           },
#           {
#             "name": "Cache All",
#             "code": "CACHE_All"
#           },
#           {
#             "name": "Altamont",
#             "code": "Altamont"
#           },
#           {
#             "name": "Duchesne",
#             "code": "Duchesne"
#           },
#           {
#             "name": "Myton",
#             "code": "Myton"
#           },
#           {
#             "name": "Roosevelt",
#             "code": "Roosevelt"
#           },
#           {
#             "name": "Tabiona",
#             "code": "Tabiona"
#           },
#           {
#             "name": "Duchesne All",
#             "code": "DUCHESNE_All"
#           },
#           {
#             "name": "Bountiful",
#             "code": " Bountiful"
#           },
#           {
#             "name": "Centerville",
#             "code": "Centerville"
#           },
#           {
#             "name": "Clearfield",
#             "code": "Clearfield"
#           },
#           {
#             "name": "Clinton",
#             "code": "Clinton"
#           },
#           {
#             "name": "Farmington",
#             "code": "Farmington"
#           },
#           {
#             "name": "Fruit Heights",
#             "code": "Fruit Heights"
#           },
#           {
#             "name": "Kaysville",
#             "code": "Kaysville"
#           },
#           {
#             "name": "Layton",
#             "code": "Layton"
#           },
#           {
#             "name": "North Salt Lake",
#             "code": "North Salt Lake"
#           },
#           {
#             "name": "South Weber",
#             "code": "South Weber"
#           },
#           {
#             "name": "Sunset",
#             "code": "Sunset"
#           },
#           {
#             "name": "Syracuse",
#             "code": "Syracuse"
#           },
#           {
#             "name": "West Bountiful",
#             "code": "West Bountiful"
#           },
#           {
#             "name": "West Point",
#             "code": "West Point"
#           },
#           {
#             "name": "Woods Cross",
#             "code": "Woods Cross"
#           },
#           {
#             "name": "Davis All",
#             "code": "DAVIS_All"
#           },
#           {
#             "name": "Delta",
#             "code": "Delta"
#           },
#           {
#             "name": "Fillmore",
#             "code": "Fillmore"
#           },
#           {
#             "name": "Hinckley",
#             "code": "Hinckley"
#           },
#           {
#             "name": "Holden",
#             "code": "Holden"
#           },
#           {
#             "name": "Kanosh",
#             "code": "Kanosh"
#           },
#           {
#             "name": "Leamington",
#             "code": "Leamington"
#           },
#           {
#             "name": "Lynndyl",
#             "code": "Lynndyl"
#           },
#           {
#             "name": "Meadow",
#             "code": "Meadow"
#           },
#           {
#             "name": "Oak City",
#             "code": "Oak City"
#           },
#           {
#             "name": "Scipio",
#             "code": "Scipio"
#           },
#           {
#             "name": "Millard All",
#             "code": "MILLARD_All"
#           },
#           {
#             "name": "Charleston",
#             "code": "Charleston"
#           },
#           {
#             "name": "Daniel",
#             "code": "Daniel"
#           },
#           {
#             "name": "Heber City",
#             "code": "Heber City"
#           },
#           {
#             "name": "Hideout",
#             "code": "Hideout"
#           },
#           {
#             "name": "Independence",
#             "code": "Independence"
#           },
#           {
#             "name": "Interlaken",
#             "code": "Interlaken"
#           },
#           {
#             "name": "Midway",
#             "code": "Midway"
#           },
#           {
#             "name": "Park City",
#             "code": "Park City"
#           },
#           {
#             "name": "Wallsburg",
#             "code": "Wallsburg"
#           },
#           {
#             "name": "Wasatch All",
#             "code": "WASATCH_All"
#           },
#           {
#             "name": "Bear River City",
#             "code": "Bear River City"
#           },
#           {
#             "name": "Brigham City",
#             "code": "Brigham City"
#           },
#           {
#             "name": "Corinne",
#             "code": "Corinne"
#           },
#           {
#             "name": "Deweyville",
#             "code": "Deweyville"
#           },
#           {
#             "name": "Elwood",
#             "code": "Elwood"
#           },
#           {
#             "name": "Fielding",
#             "code": "Fielding"
#           },
#           {
#             "name": "Garland",
#             "code": "Garland"
#           },
#           {
#             "name": "Honeyville",
#             "code": "Honeyville"
#           },
#           {
#             "name": "Howell",
#             "code": "Howell"
#           },
#           {
#             "name": "Mantua",
#             "code": "Mantua"
#           },
#           {
#             "name": "Perry",
#             "code": "Perry"
#           },
#           {
#             "name": "Plymouth",
#             "code": "Plymouth"
#           },
#           {
#             "name": "Portage",
#             "code": "Portage"
#           },
#           {
#             "name": "Snowville",
#             "code": "Snowville"
#           },
#           {
#             "name": "Tremonton",
#             "code": "Tremonton"
#           },
#           {
#             "name": "Box Elder All",
#             "code": "BOX ELDER_All"
#           },
#           {
#             "name": "Farr West",
#             "code": "Farr West"
#           },
#           {
#             "name": "Harrisville",
#             "code": "Harrisville"
#           },
#           {
#             "name": "Hooper",
#             "code": "Hooper"
#           },
#           {
#             "name": "Huntsville",
#             "code": "Huntsville"
#           },
#           {
#             "name": "Marriott-Slaterville",
#             "code": "Marriott-Slaterville"
#           },
#           {
#             "name": "North Ogden",
#             "code": "North Ogden"
#           },
#           {
#             "name": "Ogden",
#             "code": "Ogden"
#           },
#           {
#             "name": "Plain City",
#             "code": "Plain City"
#           },
#           {
#             "name": "Pleasant View",
#             "code": "Pleasant View"
#           },
#           {
#             "name": "Riverdale",
#             "code": "Riverdale"
#           },
#           {
#             "name": "Roy",
#             "code": "Roy"
#           },
#           {
#             "name": "South Ogden",
#             "code": "South Ogden"
#           },
#           {
#             "name": "Uintah",
#             "code": "Uintah"
#           },
#           {
#             "name": "Washington Terrace",
#             "code": "Washington Terrace"
#           },
#           {
#             "name": "West Haven",
#             "code": "West Haven"
#           },
#           {
#             "name": "Weber All",
#             "code": "WEBER_All"
#           },
#           {
#             "name": "Eureka",
#             "code": "Eureka"
#           },
#           {
#             "name": "Levan",
#             "code": "Levan"
#           },
#           {
#             "name": "Mona",
#             "code": "Mona"
#           },
#           {
#             "name": "Nephi",
#             "code": "Nephi"
#           },
#           {
#             "name": "Rocky Ridge",
#             "code": "Rocky Ridge"
#           },
#           {
#             "name": "Santaquin",
#             "code": "Santaquin"
#           },
#           {
#             "name": "Juab All",
#             "code": "JUAB_All"
#           },
#           {
#             "name": "Centerfield",
#             "code": "Centerfield"
#           },
#           {
#             "name": "Ephraim",
#             "code": "Ephraim"
#           },
#           {
#             "name": "Fairview",
#             "code": "Fairview"
#           },
#           {
#             "name": "Fayette",
#             "code": "Fayette"
#           },
#           {
#             "name": "Fountain Green",
#             "code": "Fountain Green"
#           },
#           {
#             "name": "Gunnison",
#             "code": "Gunnison"
#           },
#           {
#             "name": "Manti",
#             "code": "Manti"
#           },
#           {
#             "name": "Mayfield",
#             "code": "Mayfield"
#           },
#           {
#             "name": "Moroni",
#             "code": "Moroni"
#           },
#           {
#             "name": "Mount Pleasant",
#             "code": "Mount Pleasant"
#           },
#           {
#             "name": "Spring City",
#             "code": "Spring City"
#           },
#           {
#             "name": "Sterling",
#             "code": "Sterling"
#           },
#           {
#             "name": "Wales",
#             "code": "Wales"
#           },
#           {
#             "name": "Sanpete All",
#             "code": "SANPETE_All"
#           },
#           {
#             "name": "Apple Valley",
#             "code": "Apple Valley"
#           },
#           {
#             "name": "Enterprise",
#             "code": "Enterprise"
#           },
#           {
#             "name": "Hilldale",
#             "code": "Hilldale"
#           },
#           {
#             "name": "Hurricane",
#             "code": "Hurricane"
#           },
#           {
#             "name": "Ivins",
#             "code": "Ivins"
#           },
#           {
#             "name": "La Verkin",
#             "code": "La Verkin"
#           },
#           {
#             "name": "Leeds",
#             "code": "Leeds"
#           },
#           {
#             "name": "New Harmony",
#             "code": "New Harmony"
#           },
#           {
#             "name": "Rockville",
#             "code": "Rockville"
#           },
#           {
#             "name": "Santa Clara",
#             "code": "Santa Clara"
#           },
#           {
#             "name": "Springdale",
#             "code": "Springdale"
#           },
#           {
#             "name": "St. George",
#             "code": "St. George"
#           },
#           {
#             "name": "Toquerville",
#             "code": "Toquerville"
#           },
#           {
#             "name": "Virgin",
#             "code": "Virgin"
#           },
#           {
#             "name": "Washington",
#             "code": "Washington"
#           },
#           {
#             "name": "Washington All",
#             "code": "WASHINGTON_All"
#           },
#           {
#             "name": "Castle Valley",
#             "code": "Castle Valley"
#           },
#           {
#             "name": "Moab",
#             "code": "Moab"
#           },
#           {
#             "name": "Grand All",
#             "code": "GRAND_All"
#           },
#           {
#             "name": "Garden City",
#             "code": "Garden City"
#           },
#           {
#             "name": "Laketown",
#             "code": "Laketown"
#           },
#           {
#             "name": "Randolph",
#             "code": "Randolph"
#           },
#           {
#             "name": "Woodruff",
#             "code": "Woodruff"
#           },
#           {
#             "name": "Rich All",
#             "code": "RICH_All"
#           },
#           {
#             "name": "East Carbon",
#             "code": "East Carbon"
#           },
#           {
#             "name": "Helper",
#             "code": "Helper"
#           },
#           {
#             "name": "Price",
#             "code": "Price"
#           },
#           {
#             "name": "Scofield",
#             "code": "Scofield"
#           },
#           {
#             "name": "Wellington",
#             "code": "Wellington"
#           },
#           {
#             "name": "Carbon All",
#             "code": "CARBON_All"
#           },
#           {
#             "name": "Dutch John",
#             "code": "Dutch John"
#           },
#           {
#             "name": "Manila",
#             "code": "Manila"
#           },
#           {
#             "name": "Daggett All",
#             "code": "DAGGETT_All"
#           },
#           {
#             "name": "Beaver",
#             "code": "Beaver"
#           },
#           {
#             "name": "Milford",
#             "code": "Milford"
#           },
#           {
#             "name": "Minersville",
#             "code": "Minersville"
#           },
#           {
#             "name": "Beaver All",
#             "code": "BEAVER_All"
#           },
#           {
#             "name": "Annabella",
#             "code": "Annabella"
#           },
#           {
#             "name": "Aurora",
#             "code": "Aurora"
#           },
#           {
#             "name": "Central Valley",
#             "code": "Central Valley"
#           },
#           {
#             "name": "Elsinore",
#             "code": "Elsinore"
#           },
#           {
#             "name": "Glenwood",
#             "code": "Glenwood"
#           },
#           {
#             "name": "Joseph",
#             "code": "Joseph"
#           },
#           {
#             "name": "Koosharem",
#             "code": "Koosharem"
#           },
#           {
#             "name": "Monroe",
#             "code": "Monroe"
#           },
#           {
#             "name": "Redmond",
#             "code": "Redmond"
#           },
#           {
#             "name": "Richfield",
#             "code": "Richfield"
#           },
#           {
#             "name": "Salina",
#             "code": "Salina"
#           },
#           {
#             "name": "Sigurd",
#             "code": "Sigurd"
#           },
#           {
#             "name": "Sevier All",
#             "code": "SEVIER_All"
#           },
#           {
#             "name": "Antimony",
#             "code": "Anitmony"
#           },
#           {
#             "name": "Boulder",
#             "code": "Boulder"
#           },
#           {
#             "name": "Bryce Canyon City",
#             "code": "Bryce Canyon City"
#           },
#           {
#             "name": "Cannonville",
#             "code": "Cannonville"
#           },
#           {
#             "name": "Escalante",
#             "code": "Escalante"
#           },
#           {
#             "name": "Hatch",
#             "code": "Hatch"
#           },
#           {
#             "name": "Henrieville",
#             "code": "Henrieville"
#           },
#           {
#             "name": "Panguitch",
#             "code": "Panguitch"
#           },
#           {
#             "name": "Tropic",
#             "code": "Tropic"
#           },
#           {
#             "name": "Garfield All",
#             "code": "GARFIELD_All"
#           },
#           {
#             "name": "Grantsville",
#             "code": "Grantsville"
#           },
#           {
#             "name": "Rush Valley",
#             "code": "Rush Valley"
#           },
#           {
#             "name": "Stockton",
#             "code": "Stockton"
#           },
#           {
#             "name": "Tooele",
#             "code": "Tooele"
#           },
#           {
#             "name": "Vernon",
#             "code": "Vernon"
#           },
#           {
#             "name": "Wendover",
#             "code": "Wendover"
#           },
#           {
#             "name": "Tooele All",
#             "code": "TOOELE_All"
#           },
#           {
#             "name": "Coalville",
#             "code": "Coalville"
#           },
#           {
#             "name": "Francis",
#             "code": "Francis"
#           },
#           {
#             "name": "Henefer",
#             "code": "Henefer"
#           },
#           {
#             "name": "Kamas",
#             "code": "Kamas"
#           },
#           {
#             "name": "Oakley",
#             "code": "Oakley"
#           },
#           {
#             "name": "Park City (Summit)",
#             "code": "Park City (Summit)"
#           },
#           {
#             "name": "Summit All",
#             "code": "SUMMIT_All"
#           },
#           {
#             "name": "Circleville",
#             "code": "Circleville"
#           },
#           {
#             "name": "Junction",
#             "code": "Junction"
#           },
#           {
#             "name": "Kingston",
#             "code": "Kingston"
#           },
#           {
#             "name": "Marysvale",
#             "code": "Marysvale"
#           },
#           {
#             "name": "Piute All",
#             "code": "PIUTE_All"
#           },
#           {
#             "name": "Ballard",
#             "code": "Ballard"
#           },
#           {
#             "name": "Naples",
#             "code": "Naples"
#           },
#           {
#             "name": "Vernal",
#             "code": "Vernal"
#           },
#           {
#             "name": "Uintah All",
#             "code": "UINTAH_All"
#           },
#           {
#             "name": "Brian Head",
#             "code": "Brian Head"
#           },
#           {
#             "name": "Cedar City",
#             "code": "Cedar City"
#           },
#           {
#             "name": "Enoch",
#             "code": "Enoch"
#           },
#           {
#             "name": "Kanarraville",
#             "code": "Kanarraville"
#           },
#           {
#             "name": "Paragonah",
#             "code": "Paragonah"
#           },
#           {
#             "name": "Parowan",
#             "code": "Parowan"
#           },
#           {
#             "name": "Iron All",
#             "code": "IRON_All"
#           },
#           {
#             "name": "Castle Dale",
#             "code": "Castle Dale"
#           },
#           {
#             "name": "Clawson",
#             "code": "Clawson"
#           },
#           {
#             "name": "Cleveland",
#             "code": "Cleveland"
#           },
#           {
#             "name": "Elmo",
#             "code": "Elmo"
#           },
#           {
#             "name": "Emery",
#             "code": "Emery"
#           },
#           {
#             "name": "Ferron",
#             "code": "Ferron"
#           },
#           {
#             "name": "Green River",
#             "code": "Green River"
#           },
#           {
#             "name": "Huntington",
#             "code": "Huntington"
#           },
#           {
#             "name": "Orangeville",
#             "code": "Orangeville"
#           },
#           {
#             "name": "Emery All",
#             "code": "EMERY_All"
#           },
#           {
#             "name": "Bicknell",
#             "code": "Bicknell"
#           },
#           {
#             "name": "Hanksville",
#             "code": "Hanksville"
#           },
#           {
#             "name": "Loa",
#             "code": "Loa"
#           },
#           {
#             "name": "Lyman",
#             "code": "Lyman"
#           },
#           {
#             "name": "Torrey",
#             "code": "Torrey"
#           },
#           {
#             "name": "Wayne All",
#             "code": "WAYNE_All"
#           },
#           {
#             "name": "Blanding",
#             "code": "Blanding"
#           },
#           {
#             "name": "Bluff",
#             "code": "Bluff"
#           },
#           {
#             "name": "Monticello",
#             "code": "Monticello"
#           },
#           {
#             "name": "San Juan All",
#             "code": "SAN JUAN_All"
#           },
#           {
#             "name": "Morgan",
#             "code": "Morgan"
#           },
#           {
#             "name": "Morgan All",
#             "code": "MORGAN_All"
#           },
#           {
#             "name": "Alton",
#             "code": "Alton"
#           },
#           {
#             "name": "Big Water",
#             "code": "Big Water"
#           },
#           {
#             "name": "Glendale",
#             "code": "Glendale"
#           },
#           {
#             "name": "Kanab",
#             "code": "Kanab"
#           },
#           {
#             "name": "Orderville",
#             "code": "Orderville"
#           },
#           {
#             "name": "Kane All",
#             "code": "KANE_All"
#           },
#           {
#             "name": "Alta",
#             "code": "Alta"
#           },
#           {
#             "name": "Bluffdale",
#             "code": "Bluffdale"
#           },
#           {
#             "name": "Brighton",
#             "code": "Brighton"
#           },
#           {
#             "name": "Cottonwood Heights",
#             "code": "Cottonwood Heights"
#           },
#           {
#             "name": "Draper",
#             "code": "Draper"
#           },
#           {
#             "name": "Herriman",
#             "code": "Herriman"
#           },
#           {
#             "name": "Holladay",
#             "code": "Holladay"
#           },
#           {
#             "name": "Midvale",
#             "code": "Midvale"
#           },
#           {
#             "name": "Millcreek",
#             "code": "Millcreek"
#           },
#           {
#             "name": "Murray",
#             "code": "Murray"
#           },
#           {
#             "name": "Riverton",
#             "code": "Riverton"
#           },
#           {
#             "name": "Salt Lake City",
#             "code": "Salt Lake City"
#           },
#           {
#             "name": "Sandy",
#             "code": "Sandy"
#           },
#           {
#             "name": "South Jordan",
#             "code": "South Jordan"
#           },
#           {
#             "name": "South Salt Lake",
#             "code": "South Salt Lake"
#           },
#           {
#             "name": "Taylorsville",
#             "code": "Taylorsville"
#           },
#           {
#             "name": "West Jordan",
#             "code": "West Jordan"
#           },
#           {
#             "name": "West Valley City",
#             "code": "West Valley City"
#           },
#           {
#             "name": "Salt Lake All",
#             "code": "SALT LAKE_All"
#           },
#           {
#             "name": "Alpine",
#             "code": "Alpine"
#           },
#           {
#             "name": "American Fork",
#             "code": "American Fork"
#           },
#           {
#             "name": "Bluffdale (Utah)",
#             "code": "Bluffdale (Utah)"
#           },
#           {
#             "name": "Cedar Fort",
#             "code": "Cedar Fort"
#           },
#           {
#             "name": "Cedar Hills",
#             "code": "Cedar Hills"
#           },
#           {
#             "name": "Draper (Utah)",
#             "code": "Draper (Utah)"
#           },
#           {
#             "name": "Eagle Mountain",
#             "code": "Eagle Mountain"
#           },
#           {
#             "name": "Elk Ridge",
#             "code": "Elk Ridge"
#           },
#           {
#             "name": "Fairfield",
#             "code": "Fairfield"
#           },
#           {
#             "name": "Genola",
#             "code": "Genola"
#           },
#           {
#             "name": "Goshen",
#             "code": "Goshen"
#           },
#           {
#             "name": "Highland",
#             "code": "Highland"
#           },
#           {
#             "name": "Lehi",
#             "code": "Lehi"
#           },
#           {
#             "name": "Lindon",
#             "code": "Lindon"
#           },
#           {
#             "name": "Mapleton",
#             "code": "Mapleton"
#           },
#           {
#             "name": "Orem",
#             "code": "Orem"
#           },
#           {
#             "name": "Payson",
#             "code": "Payson"
#           },
#           {
#             "name": "Pleasant Grove",
#             "code": "Pleasant Grove"
#           },
#           {
#             "name": "Provo",
#             "code": "Provo"
#           },
#           {
#             "name": "Salem",
#             "code": "Salem"
#           },
#           {
#             "name": "Santaquin (Utah)",
#             "code": "Santaquin (Utah)"
#           },
#           {
#             "name": "Saratoga Springs",
#             "code": "Saratoga Springs"
#           },
#           {
#             "name": "Spanish Fork",
#             "code": "Spanish Fork"
#           },
#           {
#             "name": "Springville",
#             "code": "Springville"
#           },
#           {
#             "name": "Vineyard",
#             "code": "Vineyard"
#           },
#           {
#             "name": "Woodland Hills",
#             "code": "Woodland Hills"
#           },
#           {
#             "name": "Utah All",
#             "code": "UTAH_All"
#           }
#         ]
#       },
#       "defaultValue": null
#     },
#     {
#       "name": "assessor_name",
#       "type": "esriFieldTypeString",
#       "alias": "Assessor Name",
#       "sqlType": "sqlTypeOther",
#       "length": 255,
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "assessor_title",
#       "type": "esriFieldTypeString",
#       "alias": "Assessor Title",
#       "sqlType": "sqlTypeOther",
#       "length": 255,
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "assessor_contact",
#       "type": "esriFieldTypeString",
#       "alias": "Assessor Contact Number or Email",
#       "sqlType": "sqlTypeOther",
#       "length": 255,
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "asset_name",
#       "type": "esriFieldTypeString",
#       "alias": "Asset Name",
#       "sqlType": "sqlTypeOther",
#       "length": 255,
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "date_completed",
#       "type": "esriFieldTypeDate",
#       "alias": "Date Assessment Completed",
#       "sqlType": "sqlTypeOther",
#       "length": 8,
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null,
#       "precision": 1
#     },
#     {
#       "name": "CityID",
#       "type": "esriFieldTypeString",
#       "alias": "Asset City: (delete?)",
#       "sqlType": "sqlTypeOther",
#       "length": 255,
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "CountyID",
#       "type": "esriFieldTypeString",
#       "alias": "Asset County: (delete?)",
#       "sqlType": "sqlTypeOther",
#       "length": 255,
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "min_lat",
#       "type": "esriFieldTypeString",
#       "alias": "Minimum Latitude (delete?)",
#       "sqlType": "sqlTypeOther",
#       "length": 255,
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "max_lat",
#       "type": "esriFieldTypeString",
#       "alias": "Maximum Latitude",
#       "sqlType": "sqlTypeOther",
#       "length": 255,
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "min_long",
#       "type": "esriFieldTypeString",
#       "alias": "Minimum Longitude",
#       "sqlType": "sqlTypeOther",
#       "length": 255,
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "max_long",
#       "type": "esriFieldTypeString",
#       "alias": "Maximum Longitude",
#       "sqlType": "sqlTypeOther",
#       "length": 255,
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "boundary_json",
#       "type": "esriFieldTypeString",
#       "alias": "boundary_json",
#       "sqlType": "sqlTypeOther",
#       "length": 10000,
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "json_place",
#       "type": "esriFieldTypeString",
#       "alias": "Geopoint Place",
#       "sqlType": "sqlTypeOther",
#       "length": 255,
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "Location_within_boundary",
#       "type": "esriFieldTypeString",
#       "alias": "Is the location within the boundary?",
#       "sqlType": "sqlTypeOther",
#       "length": 255,
#       "nullable": true,
#       "editable": true,
#       "domain": null,
#       "defaultValue": null
#     },
#     {
#       "name": "infrastructure_sector",
#       "type": "esriFieldTypeString",
#       "alias": "Infrastructure Sector",
#       "sqlType": "sqlTypeOther",
#       "length": 255,
#       "nullable": true,
#       "editable": true,
#       "domain": {
#         "type": "codedValue",
#         "name": "cvd_infrastructure_sector",
#         "mergePolicy": "esriMPTDefaultValue",
#         "splitPolicy": "esriSPTDefaultValue",
#         "codedValues": [
#           {
#             "name": "Agriculture and Food",
#             "code": "Agriculture_and_Food"
#           },
#           {
#             "name": "Banking and Finance",
#             "code": "Banking_and_Finance"
#           },
#           {
#             "name": "Chemical",
#             "code": "Chemical"
#           },
#           {
#             "name": "Commercial Facilities",
#             "code": "Commercial_Facilities"
#           },
#           {
#             "name": "Critical Manufacturing",
#             "code": "Critical_Manufacturing"
#           },
#           {
#             "name": "Dams",
#             "code": "Dams"
#           },
#           {
#             "name": "Defense Industrial Base",
#             "code": "Defense_Industrial_Base"
#           },
#           {
#             "name": "Emergency Services",
#             "code": "Emergency_Services"
#           },
#           {
#             "name": "Energy",
#             "code": "Energy"
#           },
#           {
#             "name": "Government Facilities",
#             "code": "Government_Facilities"
#           },
#           {
#             "name": "Public Health and Health Care",
#             "code": "Public_Health"
#           },
#           {
#             "name": "Information Technologies",
#             "code": "Information_Technologies"
#           },
#           {
#             "name": "Nuclear Reactors, Materials, and Waste",
#             "code": "Nuclear_Reactors_Materials"
#           },
#           {
#             "name": "Telecommunication",
#             "code": "Telecommunication"
#           },
#           {
#             "name": "Transportation",
#             "code": "Transportation"
#           },
#           {
#             "name": "Water and Water Treatment",
#             "code": "Water_and_Water_Treatment"
#           }
#         ]
#       },
#       "defaultValue": null
#     },
#     {
#       "name": "other",
#       "type": "esriFieldTypeString",
# ...
#         },
#         "Public_Access_Number": {
#           "type": "inherited"
#         },
#         "Surrounding_Population_Number": {
#           "type": "inherited"
#         },
#         "Potential_Disasters_Number": {
#           "type": "inherited"
#         },
#         "Executive_Adjustment_Number": {
#           "type": "inherited"
#         },
#         "Hazardous_Number": {
#           "type": "inherited"
#         },
#         "Backup_Generator": {
#           "type": "inherited"
#         },
#         "Gernerator_Fuel_Storage": {
#           "type": "inherited"
#         }
#       },
#       "templates": [
#         {
#           "name": "Public_Health",
#           "description": "",
#           "drawingTool": "esriFeatureEditToolPoint",
#           "prototype": {
#             "attributes": {
#               "Generator_Fuel": null,
#               "Backup_Generator": null,
#               "Gernerator_Fuel_Storage": null,
#               "county": null,
#               "Utah_City": null,
#               "assessor_name": null,
#               "assessor_title": null,
#               "assessor_contact": null,
#               "asset_name": null,
#               "date_completed": null,
#               "CityID": null,
#               "CountyID": null,
#               "min_lat": null,
#               "max_lat": null,
#               "min_long": null,
#               "max_long": null,
#               "boundary_json": null,
#               "json_place": null,
#               "Location_within_boundary": null,
#               "infrastructure_sector": "Public_Health",
#               "other": null,
#               "symbolic_type": null,
#               "building_occupancy": null,
#               "seismic_design": null,
#               "construction_type": null,
#               "year_built": null,
#               "replacement_cost": null,
#               "square_footage": null,
#               "daytime_occupancy": null,
#               "nighttime_occupancy": null,
#               "no_stories": null,
#               "contents_cost": null,
#               "foundation_type": null,
#               "first_floor_height": null,
#               "token": null,
#               "countyequals": null,
#               "more_notes": null,
#               "infrastructure_sub": null,
#               "asset_address": null,
#               "address_notes": null,
#               "infrastructure_other": null,
#               "Total_Score_Number": null,
#               "delete_asset": null,
#               "sure_delete": null,
#               "System_Importance_Number": null,
#               "Site_Occupancy_Number": null,
#               "Symbolic_Number": null,
#               "Economic_Number": null,
#               "Critical_Service_Number": null,
#               "Public_Access_Number": null,
#               "Surrounding_Population_Number": null,
#               "Potential_Disasters_Number": null,
#               "Executive_Adjustment_Number": null,
#               "Hazardous_Number": null,
#               "state_agency": "N/A",
#               "asset_owner": null,
#               "asset_hours": null,
#               "building_type": null,
#               "match_jurisdiction": null,
#               "out_of_bounds_note": null
#             }
#           }
#         }
#       ]
#     },
#     {
#       "id": "Telecommunication",
#       "name": "Telecommunication",
#       "domains": {
#         "county": {
#           "type": "inherited"
#         },
#         "Utah_City": {
#           "type": "inherited"
#         },
#         "infrastructure_sector": {
#           "type": "inherited"
#         },
#         "symbolic_type": {
#           "type": "inherited"
#         },
#         "infrastructure_sub": {
#           "type": "inherited"
#         },
#         "System_Importance_Number": {
#           "type": "inherited"
#         },
#         "Site_Occupancy_Number": {
#           "type": "inherited"
#         },
#         "Symbolic_Number": {
#           "type": "inherited"
#         },
#         "Economic_Number": {
#           "type": "inherited"
#         },
#         "Critical_Service_Number": {
#           "type": "inherited"
#         },
#         "Public_Access_Number": {
#           "type": "inherited"
#         },
#         "Surrounding_Population_Number": {
#           "type": "inherited"
#         },
#         "Potential_Disasters_Number": {
#           "type": "inherited"
#         },
#         "Executive_Adjustment_Number": {
#           "type": "inherited"
#         },
#         "Hazardous_Number": {
#           "type": "inherited"
#         },
#         "Backup_Generator": {
#           "type": "inherited"
#         },
#         "Gernerator_Fuel_Storage": {
#           "type": "inherited"
#         }
#       },
#       "templates": [
#         {
#           "name": "Telecommunication",
#           "description": "",
#           "drawingTool": "esriFeatureEditToolPoint",
#           "prototype": {
#             "attributes": {
#               "Generator_Fuel": null,
#               "Backup_Generator": null,
#               "Gernerator_Fuel_Storage": null,
#               "county": null,
#               "Utah_City": null,
#               "assessor_name": null,
#               "assessor_title": null,
#               "assessor_contact": null,
#               "asset_name": null,
#               "date_completed": null,
#               "CityID": null,
#               "CountyID": null,
#               "min_lat": null,
#               "max_lat": null,
#               "min_long": null,
#               "max_long": null,
#               "boundary_json": null,
#               "json_place": null,
#               "Location_within_boundary": null,
#               "infrastructure_sector": "Telecommunication",
#               "other": null,
#               "symbolic_type": null,
#               "building_occupancy": null,
#               "seismic_design": null,
#               "construction_type": null,
#               "year_built": null,
#               "replacement_cost": null,
#               "square_footage": null,
#               "daytime_occupancy": null,
#               "nighttime_occupancy": null,
#               "no_stories": null,
#               "contents_cost": null,
#               "foundation_type": null,
#               "first_floor_height": null,
#               "token": null,
#               "countyequals": null,
#               "more_notes": null,
#               "infrastructure_sub": null,
#               "asset_address": null,
#               "address_notes": null,
#               "infrastructure_other": null,
#               "Total_Score_Number": null,
#               "delete_asset": null,
#               "sure_delete": null,
#               "System_Importance_Number": null,
#               "Site_Occupancy_Number": null,
#               "Symbolic_Number": null,
#               "Economic_Number": null,
#               "Critical_Service_Number": null,
#               "Public_Access_Number": null,
#               "Surrounding_Population_Number": null,
#               "Potential_Disasters_Number": null,
#               "Executive_Adjustment_Number": null,
#               "Hazardous_Number": null,
#               "state_agency": "N/A",
#               "asset_owner": null,
#               "asset_hours": null,
#               "building_type": null,
#               "match_jurisdiction": null,
#               "out_of_bounds_note": null
#             }
#           }
#         }
#       ]
#     },
#     {
#       "id": "Transportation",
#       "name": "Transportation",
#       "domains": {
#         "county": {
#           "type": "inherited"
#         },
#         "Utah_City": {
#           "type": "inherited"
#         },
#         "infrastructure_sector": {
#           "type": "inherited"
#         },
#         "symbolic_type": {
#           "type": "inherited"
#         },
#         "infrastructure_sub": {
#           "type": "inherited"
#         },
#         "System_Importance_Number": {
#           "type": "inherited"
#         },
#         "Site_Occupancy_Number": {
#           "type": "inherited"
#         },
#         "Symbolic_Number": {
#           "type": "inherited"
#         },
#         "Economic_Number": {
#           "type": "inherited"
#         },
#         "Critical_Service_Number": {
#           "type": "inherited"
#         },
#         "Public_Access_Number": {
#           "type": "inherited"
#         },
#         "Surrounding_Population_Number": {
#           "type": "inherited"
#         },
#         "Potential_Disasters_Number": {
#           "type": "inherited"
#         },
#         "Executive_Adjustment_Number": {
#           "type": "inherited"
#         },
#         "Hazardous_Number": {
#           "type": "inherited"
#         },
#         "Backup_Generator": {
#           "type": "inherited"
#         },
#         "Gernerator_Fuel_Storage": {
#           "type": "inherited"
#         }
#       },
#       "templates": [
#         {
#           "name": "Transportation",
#           "description": "",
#           "drawingTool": "esriFeatureEditToolPoint",
#           "prototype": {
#             "attributes": {
#               "Generator_Fuel": null,
#               "Backup_Generator": null,
#               "Gernerator_Fuel_Storage": null,
#               "county": null,
#               "Utah_City": null,
#               "assessor_name": null,
#               "assessor_title": null,
#               "assessor_contact": null,
#               "asset_name": null,
#               "date_completed": null,
#               "CityID": null,
#               "CountyID": null,
#               "min_lat": null,
#               "max_lat": null,
#               "min_long": null,
#               "max_long": null,
#               "boundary_json": null,
#               "json_place": null,
#               "Location_within_boundary": null,
#               "infrastructure_sector": "Transportation",
#               "other": null,
#               "symbolic_type": null,
#               "building_occupancy": null,
#               "seismic_design": null,
#               "construction_type": null,
#               "year_built": null,
#               "replacement_cost": null,
#               "square_footage": null,
#               "daytime_occupancy": null,
#               "nighttime_occupancy": null,
#               "no_stories": null,
#               "contents_cost": null,
#               "foundation_type": null,
#               "first_floor_height": null,
#               "token": null,
#               "countyequals": null,
#               "more_notes": null,
#               "infrastructure_sub": null,
#               "asset_address": null,
#               "address_notes": null,
#               "infrastructure_other": null,
#               "Total_Score_Number": null,
#               "delete_asset": null,
#               "sure_delete": null,
#               "System_Importance_Number": null,
#               "Site_Occupancy_Number": null,
#               "Symbolic_Number": null,
#               "Economic_Number": null,
#               "Critical_Service_Number": null,
#               "Public_Access_Number": null,
#               "Surrounding_Population_Number": null,
#               "Potential_Disasters_Number": null,
#               "Executive_Adjustment_Number": null,
#               "Hazardous_Number": null,
#               "state_agency": "N/A",
#               "asset_owner": null,
#               "asset_hours": null,
#               "building_type": null,
#               "match_jurisdiction": null,
#               "out_of_bounds_note": null
#             }
#           }
#         }
#       ]
#     },
#     {
#       "id": "Water_and_Water_Treatment",
#       "name": "Water and Water Treatment",
#       "domains": {
#         "county": {
#           "type": "inherited"
#         },
#         "Utah_City": {
#           "type": "inherited"
#         },
#         "infrastructure_sector": {
#           "type": "inherited"
#         },
#         "symbolic_type": {
#           "type": "inherited"
#         },
#         "infrastructure_sub": {
#           "type": "inherited"
#         },
#         "System_Importance_Number": {
#           "type": "inherited"
#         },
#         "Site_Occupancy_Number": {
#           "type": "inherited"
#         },
#         "Symbolic_Number": {
#           "type": "inherited"
#         },
#         "Economic_Number": {
#           "type": "inherited"
#         },
#         "Critical_Service_Number": {
#           "type": "inherited"
#         },
#         "Public_Access_Number": {
#           "type": "inherited"
#         },
#         "Surrounding_Population_Number": {
#           "type": "inherited"
#         },
#         "Potential_Disasters_Number": {
#           "type": "inherited"
#         },
#         "Executive_Adjustment_Number": {
#           "type": "inherited"
#         },
#         "Hazardous_Number": {
#           "type": "inherited"
#         },
#         "Backup_Generator": {
#           "type": "inherited"
#         },
#         "Gernerator_Fuel_Storage": {
#           "type": "inherited"
#         }
#       },
#       "templates": [
#         {
#           "name": "Water_and_Water_Treatment",
#           "description": "",
#           "drawingTool": "esriFeatureEditToolPoint",
#           "prototype": {
#             "attributes": {
#               "Generator_Fuel": null,
#               "Backup_Generator": null,
#               "Gernerator_Fuel_Storage": null,
#               "county": null,
#               "Utah_City": null,
#               "assessor_name": null,
#               "assessor_title": null,
#               "assessor_contact": null,
#               "asset_name": null,
#               "date_completed": null,
#               "CityID": null,
#               "CountyID": null,
#               "min_lat": null,
#               "max_lat": null,
#               "min_long": null,
#               "max_long": null,
#               "boundary_json": null,
#               "json_place": null,
#               "Location_within_boundary": null,
#               "infrastructure_sector": "Water_and_Water_Treatment",
#               "other": null,
#               "symbolic_type": null,
#               "building_occupancy": null,
#               "seismic_design": null,
#               "construction_type": null,
#               "year_built": null,
#               "replacement_cost": null,
#               "square_footage": null,
#               "daytime_occupancy": null,
#               "nighttime_occupancy": null,
#               "no_stories": null,
#               "contents_cost": null,
#               "foundation_type": null,
#               "first_floor_height": null,
#               "token": null,
#               "countyequals": null,
#               "more_notes": null,
#               "infrastructure_sub": null,
#               "asset_address": null,
#               "address_notes": null,
#               "infrastructure_other": null,
#               "Total_Score_Number": null,
#               "delete_asset": null,
#               "sure_delete": null,
#               "System_Importance_Number": null,
#               "Site_Occupancy_Number": null,
#               "Symbolic_Number": null,
#               "Economic_Number": null,
#               "Critical_Service_Number": null,
#               "Public_Access_Number": null,
#               "Surrounding_Population_Number": null,
#               "Potential_Disasters_Number": null,
#               "Executive_Adjustment_Number": null,
#               "Hazardous_Number": null,
#               "state_agency": "N/A",
#               "asset_owner": null,
#               "asset_hours": null,
#               "building_type": null,
#               "match_jurisdiction": null,
#               "out_of_bounds_note": null
#             }
#           }
#         }
#       ]
#     }
#   ],
#   "templates": [],
#   "supportedQueryFormats": "JSON, geoJSON, PBF",
#   "supportedAppendFormats": "sqlite,geoPackage,shapefile,filegdb,featureCollection,geojson,csv,excel,jsonl,imageCollection",
#   "supportedExportFormats": "csv,shapefile,sqlite,geoPackage,filegdb,featureCollection,geojson,excel",
#   "supportedSpatialRelationships": [
#     "esriSpatialRelIntersects",
#     "esriSpatialRelContains",
#     "esriSpatialRelCrosses",
#     "esriSpatialRelEnvelopeIntersects",
#     "esriSpatialRelIndexIntersects",
#     "esriSpatialRelOverlaps",
#     "esriSpatialRelTouches",
#     "esriSpatialRelWithin",
#     "esriSpatialRelDisjoint",
#     "esriSpatialRelRelation"
#   ],
#   "supportedContingentValuesFormats": "JSON, PBF",
#   "supportedSyncDataOptions": 4,
#   "hasStaticData": false,
#   "maxRecordCount": 2000,
#   "standardMaxRecordCount": 32000,
#   "standardMaxRecordCountNoGeometry": 32000,
#   "tileMaxRecordCount": 8000,
#   "maxRecordCountFactor": 1,
#   "capabilities": "Create,Delete,Query,Update,Editing,Extract,Sync"
# }

# %%
# Print County Names

for index, county in enumerate(counties):
    ind = len(counties_munis) - index - 1
    county_name = counties_munis.features[ind].attributes['NAME']
    if county_name[-4:] == "_ALL": 
        print(county_name)

# %%
# Run this to delete all view layers 

if_delete = input("Do you want to delete all view layers?")
if if_delete == "yes":
    for index, county in enumerate(counties_munis):
        county_name = counties_munis.features[index].attributes['NAME']
        print(county_name)
        view_name = 'UCIP_' + county_name + "_LIVE_View"
        print(view_name)
        # Get the geometry for the regions
        view_geom = counties_munis.features[index].geometry.get('rings')
        name_avail = cm.is_service_name_available(service_name = view_name,service_type = "featureService")
        # Check if view exists
        if  name_avail == False:
            view_search = my_agol.content.search(view_name)[0]
            view_search.delete()
            print(view_name + " has been deleted.")

# %%
# Backup as FGDB
from datetime import datetime
from arcgis.gis import GIS 
import arcpy 
import os 
import zipfile 
import glob 
import shutil 

current_time = datetime.now()
date = current_time.strftime('%m_%d_%y')

fgdb_title = ucip_locs.title 
fgdb_title=fgdb_title.replace('_', '')
fgdb_title=fgdb_title+"_"+date
print(fgdb_title)

root = r"C:\UCIP" 
#result = ucip_locs.export(fgdb_title, "File Geodatabase")
#items = gis.content.search(nombre)
result = ucip_locs.export(fgdb_title, 'File Geodatabase', parameters=None, wait='True') 
result.download(root)
